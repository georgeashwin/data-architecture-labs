# %%
df = spark.read.csv("dbfs:/FileStore/datasets/authors_publications.csv", header=True, inferSchema=True)
display(df)

# %%
df.show(5)

# %%
from pyspark.sql.functions import sum

df_grouped = df.groupBy("country").agg(sum("citations").alias("total_citations"))
display(df_grouped)

# %%
df_clean = df.dropna()
display(df_clean)
